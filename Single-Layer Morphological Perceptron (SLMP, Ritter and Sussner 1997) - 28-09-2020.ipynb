# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer, make_blobs, make_moons
from sklearn.model_selection import train_test_split

# Classificadores
from sklearn.linear_model import Perceptron

# Biblioteca para criar classificador.
from sklearn.base import BaseEstimator, ClassifierMixin

# Biblioteca para visualização.
from mlxtend.plotting import plot_decision_regions

# %% [markdown]
# ## Duas Luas

# %%
X, y = make_moons(n_samples=1000, noise=.1, random_state=1)
y = 1-y
plt.scatter(X[:,0],X[:,1],c=y)
plt.grid(True)

# %% [markdown]
# ## Make Blobs

# %%
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=1)
y = 1-y
plt.scatter(X[:,0],X[:,1],c=y)
plt.grid(True)

# %%
Xtr, Xte, ytr, yte = train_test_split(X, y, test_size=0.33, random_state=42)
plt.scatter(Xtr[:,0],Xtr[:,1],c=ytr)
plt.grid(True)

# %%
K, N = Xtr.shape
K, N
# Out:
# (670, 2)

# %%
xi=7
# Xtr[xi,:], Xtr[xi,:]+w, 
print(w)
compara = ((Xtr[xi,:] + w)>0) > ytr[xi]
print(compara)
w[compara] = -Xtr[xi,compara]
print(w)
# Out:
# [ 0.81339926 -6.09894447]
# [ True False]
# [ 0.55732317 -6.09894447]

# %%
class SLMP(BaseEstimator, ClassifierMixin):
    
    def __init__(self, verbose = False, myInf = 1.e+10):
        self.verbose = verbose
        self.myInf = 1.e+10 
        
    def fit(self, Xtr, ytr):
        
        K, N = Xtr.shape
        
        # Inicializando os pesos como "infinito"
        self.w_ = (self.myInf)*np.ones(2,)
        if self.verbose:
            print("Pesos iniciais:",self.w_)
        
        for xi in range(K):
            compara = ((Xtr[xi,:] + self.w_)>0) > ytr[xi]
            self.w_[compara] = -Xtr[xi,compara]
            if self.verbose:
                print("Pesos para atualizar:",compara)
                print("Pesos atualizados:",self.w_)
        
        return self
    
    def decision_function(self,X):
        return np.max(X+self.w_,axis=1)
    
    def predict(self,X):
        return self.decision_function(X)>0

# %%
clf = SLMP()
clf.fit(Xtr,ytr)

plt.figure(figsize=(8,6))
plot_decision_regions(Xte,yte,clf=clf)
plt.grid(True)

print("Acuracias:\n Treino:", clf.score(Xtr,ytr),"\n  Teste:", clf.score(Xte,yte))
# Out:
# Acuracias:
#  Treino: 0.7671641791044777
#   Teste: 0.7878787878787878

# %%
clf = Perceptron()
clf.fit(Xtr,ytr)

plt.figure(figsize=(8,6))
plot_decision_regions(Xte,yte,clf=clf)
plt.grid(True)

print("Acuracias:\n Treino:", clf.score(Xtr,ytr),"\n  Teste:", clf.score(Xte,yte))
# Out:
# Acuracias:
#  Treino: 0.8432835820895522
#   Teste: 0.8848484848484849

# %%
np.max(Xtr+clf.w_,axis=1)
# Out:
# array([-11.23963612,  -2.47491811,  -2.81964917,  -3.32840703,
#         -3.87683489,  -2.2661481 , -10.85331805,  -2.21884202,
#        -10.93161553, -10.84604481, -10.98329979, -12.10210816,
#        -10.55968177, -12.25973569, -12.46377294,  -2.35453951,
#        -11.07261284,  -2.59552824, -12.01641888,  -3.03798759,
#         -5.0757134 ,  -9.61955909, -12.08861733,  -9.49114133,
#         -3.43706394, -10.99802321,  -3.20974149, -11.68916723,
#         -3.42753888,  -2.7122951 ,  -3.46043056,  -2.74811603,
#        -11.54632144,  -4.02822724,   0.        ,  -2.12216088,
#         -2.87086101, -11.93408177,  -1.26990531,  -2.50673563,
#        -11.32770462,  -2.84046931,  -2.50503507, -10.49362233,
#        -12.10670463, -10.01063728,  -2.5096133 , -11.76061214,
#         -2.87971431,  -9.09377857,  -2.14607489,  -1.90224718,
#         -2.73103929,  -2.33575362,  -3.36025701,  -3.37197951,
#         -2.69999606,  -5.73458176, -11.24835842, -11.32974139,
#         -3.29921592,  -2.80331482,  -3.27886501, -10.27078628,
#         -2.48209534, -10.68753487, -12.77104944,  -3.50199906,
#         -3.03633065,  -3.58006161, -13.20362714,  -1.94132056,
#         -9.52467979,  -2.60849589,  -2.83051771,  -1.98962164,
#         -3.66497947,  -2.25841456, -12.29431877,  -1.62726964,
#        -12.50080069,  -3.13357288,  -2.57361136, -11.77321353,
#        -11.99974858, -12.07894922,  -3.17431349, -10.64865764,
#        -11.47749032, -10.93854542, -12.11753339,  -3.86887359,
#         -2.10559322,  -3.47807243,  -3.26032856,  -3.4532208 ,
#         -4.19836028,  -9.97084757, -12.59091292,  -3.77719631,
#        -11.7793029 ,  -3.17943822, -14.13316821,  -5.82751941,
#        -11.31974355,  -3.58103892,  -2.10120438, -11.23622814,
#         -3.1512095 ,  -3.40116325, -10.56592472, -12.2696946 ,
#        -10.81969713, -12.59037992, -11.95838462,  -3.30455119,
#         -3.11996796, -10.99264143,  -9.94871093, -10.02595514,
#         -2.92796951,  -3.57275296, -11.14481979, -11.50381611,
#        -12.0222848 ,  -2.30252628, -12.45485797, -11.11250109,
#         -1.8696495 , -12.15994172,  -3.44323277,  -3.02090844,
#        -10.8012199 ,  -3.94642076,  -4.02147726,  -3.01110154,
#         -3.51162705,  -2.70884623,  -3.05711581, -11.1312808 ,
#         -1.86018638, -11.45021907,  -3.22557947, -10.31287954,
#         -3.42824724,  -2.5622731 ,  -3.35789641, -11.35190029,
#         -1.57626699,  -3.59675539,  -2.57772221, -10.05490741,
#        -12.20865817, -11.78012066,  -4.87402707, -11.54296095,
#         -3.63564262, -12.8281927 , -10.53148001,  -2.17417838,
#         -4.38503132, -10.57813836,  -2.46779657, -11.16971474,
#         -3.09098402, -12.93393276,  -1.66127658, -11.00705172,
#        -11.91108355, -10.57481279,  -3.91354004, -10.99251844,
#         -9.55048292,  -1.66488509,  -2.31311228,  -4.26951841,
#        -12.07672918, -10.25861347,  -1.66395412, -11.27620448,
#         -3.03549143,  -2.85443549, -12.40675762, -10.76883227,
#        -11.35453652, -12.28251135, -11.85917075, -10.99135179,
#        -10.23328933, -12.18214011, -11.09450511, -11.3831286 ,
#        -10.21378605,  -2.78991496, -12.50314284, -11.03205432,
#        -10.38660802,  -9.74716261,  -1.84799765,  -3.13451737,
#         -4.02601273,  -2.86995582,  -2.93547646, -10.02311623,
#         -3.24325763, -10.85617314,  -2.69927525,  -2.51012708,
#        -10.5039696 ,  -2.69771658, -12.65780089, -11.05619544,
#         -1.99150095, -12.04874227,  -2.94881537,  -3.60610834,
#        -10.90190323, -11.88648386,  -3.90954101,  -3.72418701,
#         -1.693428  , -11.3658933 , -11.36705931,  -2.82380966,
#         -2.72634963,  -3.00292456, -10.50226886,  -3.59680106,
#        -11.69153481, -11.24551002,  -1.93229936, -11.57119526,
#         -2.52605266, -10.33187601, -11.59451398, -11.24086944,
#         -2.80814894, -11.67096557,  -2.89155262, -12.63067078,
#         -2.73488049, -11.35918009,  -3.00544381,  -2.50049447,
#        -11.26782647, -12.92261229, -10.12998349, -11.36844341,
#         -3.18883098, -12.44863633, -10.27935145, -10.37943118,
#         -1.41642005,  -3.40252919,  -3.21304794, -10.33402987,
#        -11.56311721,  -2.8576025 ,  -3.17882738,  -2.92665073,
#        -12.05940922,  -4.04667588, -11.63805953, -10.40249388,
#        -11.28843863,   0.        , -10.78303149,  -9.76207067,
#        -10.50227647,  -3.39040745,  -2.15963877, -10.5801743 ,
#         -3.26057067, -12.56024299, -11.15124702,  -2.96720833,
#         -3.4892776 ,  -1.78454243,  -2.91081301, -12.28043869,
#         -4.17857558, -10.42093031, -10.52052175, -11.10169871,
#        -11.30457087,  -2.92319833, -11.225871  , -11.79578595,
#         -3.64194381, -11.37061464,  -3.37269227,  -2.01137285,
#        -10.38964081,  -2.77843346, -10.16282604,  -3.03715264,
#        -11.31754276, -10.73094114, -10.33950544,  -3.02588129,
#         -2.33474357, -10.36823798,  -2.94478024,  -3.31761684,
#        -11.91178547, -11.6621368 ,  -3.05543635, -10.4702206 ,
#        -11.60928395, -10.16733399,  -3.41351107,  -2.56974152,
#         -2.8975844 ,  -3.49350696,  -2.46779753, -11.83067254,
#        -12.62189392, -12.8191427 ,  -3.83817321, -11.70969204,
#         -3.67560717,  -3.27740976,  -3.12277904,  -2.92156372,
#         -2.09592291, -11.53353647, -11.36565927, -12.77419886,
#         -2.18944937,  -2.80600514,  -2.72186552,  -2.96996186,
#         -3.66606597, -10.02860156, -11.35940615,  -2.79161343,
#         -3.38013828, -11.71557812,  -2.52827189, -13.08052593,
#         -2.42022281, -10.70523912, -10.9438979 , -10.26515031,
#        -11.73528232, -12.43222268,  -3.0885842 , -11.55894753,
#         -1.82519399,  -4.40649789, -12.27597778, -10.6191929 ,
#        -12.03129603,  -2.2809896 , -11.70377853,  -2.19766659,
#         -3.2009198 , -10.9758751 ,  -3.43152578,  -9.8941345 ,
#        -10.65513825,  -9.8949463 ,  -3.33889631,  -2.52301496,
#         -2.56568673,  -3.84343522, -11.70448956, -12.93865751,
#         -3.63119553, -10.91593959, -11.83616791, -12.01464484,
#        -12.66101206, -10.12185155,  -2.71453036, -10.80369074,
#        -12.31967454, -12.04521945, -11.51269928, -12.06169898,
#        -11.47315684, -12.30572238, -11.84567263, -11.53191672,
#         -3.23689141, -11.73248833, -10.14610832,  -4.06539669,
#        -11.46015512, -10.76544725,  -2.10313786, -10.89193773,
#         -2.64100892, -11.15197977,  -9.50887755,  -2.93735458,
#        -11.17838524,  -1.51748977, -10.69520872,  -5.17194083,
#        -11.0140787 ,  -5.54819139,  -1.52972573, -11.71617599,
#         -2.85991466, -12.57307419, -11.79560386,  -3.01080647,
#        -12.13210691, -11.8468577 ,  -3.17106248, -11.85026053,
#        -12.35780202,  -2.26075125,  -4.25499341,  -4.78723068,
#         -2.15400359, -11.78073603, -10.7648759 , -11.73693184,
#         -3.76981679, -11.89993186, -10.61601107, -12.42106604,
#         -3.69636371, -12.43512618, -12.35704125, -10.88469683,
#        -11.3046293 ,  -2.92729102, -11.65183043,  -4.65303042,
#        -11.61169673,  -3.08243378,  -3.2307892 ,  -3.22720019,
#         -3.16407446, -11.28065578, -12.76676278,  -3.46344409,
#         -2.19818752,  -3.0969796 , -10.55583222, -11.08161902,
#        -10.65103574,  -3.64757825,  -2.85442838, -10.83029955,
#         -2.95053727,  -3.83005103, -11.34137347,  -3.64344331,
#         -3.32297024, -11.48415791,  -3.90148171,  -2.80050242,
#         -2.28762795, -10.66004178, -12.51905838, -11.38356728,
#        -11.97183437, -10.84363099, -11.99162814,  -3.28389118,
#        -12.79653577,  -3.43107025, -10.72903315, -10.16520765,
#         -2.8427616 ,  -1.48636113, -11.20295175,  -3.40558678,
#         -3.81220389, -10.94101497, -11.96016207, -12.23259208,
#         -2.18730931, -10.09681182,  -2.01487269,  -2.22208242,
#         -2.75654784,  -4.41853281,  -1.70412916, -11.67854736,
#        -12.2109116 ,  -3.00203966, -10.06476672, -10.35240077,
#        -11.68159073,  -0.93093279,  -3.8776756 ,  -2.89515858,
#        -10.67065327,  -2.64327119,  -2.71875948, -10.89089417,
#         -4.27314086,  -3.78664557,  -1.25529544, -11.68678402,
#        -10.31000368, -11.15386791,  -2.19064276,  -3.86685292,
#        -12.2178477 ,  -3.21485603, -11.79947175,  -0.79275305,
#        -13.17030796, -10.73547538, -10.25182076,  -2.70253963,
#         -3.8689163 ,  -9.27482622, -11.40282223,  -3.31424904,
#        -12.03225155,  -3.15320928,  -3.45705608,  -3.04457945,
#         -3.89022741,  -2.39557754,  -3.14591103, -10.78555713,
#        -10.33653737,  -3.21702537, -11.38088628, -10.65014109,
#         -9.94214262,  -1.39726333, -10.01068026, -10.4821791 ,
#        -11.3261168 ,  -3.13062806,  -2.54934931,  -4.02242318,
#        -10.32872524,  -3.63894576, -12.02839976,  -1.50923405,
#        -12.27039041,  -2.34524133, -10.38130954,  -2.66202896,
#        -11.60544895,  -1.85897082, -11.86192526,  -2.02107389,
#         -1.89746433,  -2.46049452,  -3.68369084,  -2.45567113,
#         -2.20669578, -11.4323512 ,  -1.74561085,  -3.97632102,
#         -2.99981284, -11.67434113,  -2.64668265, -11.596161  ,
#         -3.58729726,  -9.42895721,  -3.2331287 ,  -3.44154333,
#         -2.65939768,  -3.18096887,  -5.35827998,  -3.00884007,
#        -11.52035248, -12.91758127,  -3.88428215, -11.14267889,
#        -12.2918215 ,  -3.15114679,  -3.75927902,  -3.34569571,
#        -11.98037933, -12.00832505,  -3.52063947,  -4.03528207,
#         -3.22608265,  -1.85834757,  -9.82932512, -12.10541539,
#        -10.99515181, -10.27125754, -10.2858989 ,  -2.11262243,
#        -11.40102135, -10.79534441, -10.28844363,  -3.57206356,
#         -2.25311919,  -3.35736004,  -1.70016647, -11.48476231,
#        -10.75552192,  -4.84915829,  -3.6100761 ,  -2.31539208,
#        -11.27149669, -11.2331898 ,  -3.04310344, -12.47477871,
#         -2.73643215, -12.74386015, -12.03892031,  -4.32816513,
#         -9.44338802,  -2.16074019,  -3.64505498, -12.61753609,
#         -3.30772608,  -2.72964712,  -2.19966105,  -3.30391403,
#         -3.97760323,  -2.68007462,  -2.41948804, -10.78665236,
#         -2.38982308,  -9.62045421,  -1.18325069,  -2.83627438,
#        -12.11233631,  -3.5434069 ,  -9.84705426, -10.82933698,
#         -2.734095  , -11.55980406,  -3.50414074, -12.02148375,
#         -3.27076167, -11.23230703,  -2.95772128,  -3.60746367,
#        -11.38540426, -11.48338275,  -2.92248037,  -3.07840932,
#        -10.4176618 , -11.62661587, -10.34429057,  -2.1932676 ,
#         -2.40358671,  -2.30987169, -11.24354137,  -3.74393572,
#         -3.82505271,  -3.50764853,  -3.35977427, -12.06696768,
#         -4.10299044, -10.69603826, -10.88750832,  -3.70059627,
#        -10.68383862, -11.18643835,  -2.88608043,  -3.24381311,
#         -3.84925051,  -3.44396898, -10.15470949,  -4.15108974,
#         -4.28234236, -11.7601769 ,  -1.51054384,  -2.02752914,
#         -2.15979306,  -3.50765775])
